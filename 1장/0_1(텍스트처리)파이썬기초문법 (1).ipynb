# %% [markdown]
# `참고: 덕성여대 Nano-degree 교과 <중국어 빅데이터 이해와 활용>,<언어 빅데이터>`
#
# ```
# 참고문헌:
# 朴敏浚 (2016). 面向初学者的中文信息处理平台构建及应用. 数字化汉语教学 10, 227-232.
# 박민준 (2019). 중국어 어휘 유사도 계산과 언어학적 고찰. 중국학연구, 88, 37-66.
# 박민준, 이창호 (2019). 중국어 트리뱅크의 시각화. 언어와 정보사회 38.
# 박민준, 강병규 (2019). 중국어 구문분석기의 작동 원리와 응용 사례. 중국언어연구 82, 233-266.
# 박민준 (2022). 현대중국어 형태소 분석기의 현황과 활용. 중국언어연구, 102, 341-372.
# 강병규, 박민준 (2022). 중국의 자연어처리 연구 현황과 발전 추세. 언어와 정보사회, 45, 193-231.
# ```

# %% [markdown]
# # 파이썬 기초 예제

# %% [markdown]
# ## 사칙 연산
#
# *   덧셈   +
# *   뺄셈   -
# *   곱셈 *  (제곱 **)
# *   나눗셈 /  (몫 //, 나머지 %)

# %%
1+1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
2**4
# Out:
# 16

# %%
10%3
# Out:
# 1

# %% [markdown]
# 연산의 우선순위<br>
# 곱셉/나눗셈 우선 법칙 그대로 적용<br>

# %%
(5+6) / 3
# Out:
# 3.6666666666666665

# %%
6 // 3
# Out:
# 2

# %% [markdown]
# ## 변수에 값 저장하기

# %%
a = 1
b = 2

# %%
print(a)
# Out:
# 1

# %% [markdown]
# * `=` 왼쪽 변수에 오른쪽 값을 저장
# * `==` 같으니?
# * `!=` 다르니?

# %%
# = 변수에 값을 저장하기,  == 같으니 다르니?
a+b == 1+2
# Out:
#   File "<ipython-input-42-d9a60209bf0b>", line 2
#     a+b = 1+2
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ## 파이썬 기본 자료구조인 List에 저장하기<br>

# %%
z = [1,2,3]

# %%
#  print 함수 사용하여 화면에 출력하기
print(z)
# Out:
# [1, 2, 3]

# %%
b = range(1,4)
b = list(b)
print(b)
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 문자도 변수로 저장할 수 있다

# %%
a ='나는' # 문자도 변수로 저장할 수 있다
b='사랑합니다'
c='덕성여자대학교를'
space=' '

# %%
print(a+b+c)
# Out:
# 나는사랑합니다덕성여자대학교를

# %%
print(a + space + c + space + b)
# Out:
# 나는 덕성여자대학교를 사랑합니다

# %%
z = '我爱德成女子大学' # string(문자열)은 따옴표로 감싼다. 그렇지 않으면 파이썬은 변수명으로 오해한다

# %%
print(z)
# Out:
# 我爱德成女子大学

# %%
type(z) # 텍스트는 string(문자열)의 data type(자료형)으로 저장된다 # integer
# Out:
# str

# %% [markdown]
# string의 덧셈은 문자를 이어 붙인 것이다

# %%
a+b+c
# Out:
# '나는사랑합니다덕성여자대학교를'

# %%
1+2
# Out:
# 3

# %%
'1'+'2'  # 결과는? -> 문자열은 연결(concat)
# Out:
# '12'

# %% [markdown]
# ## 문자열 사용법

# %% [markdown]
# ### 문자열 만드는 방법
# - 큰따옴표 (")
# - 작은따옴표 (')

# %% [markdown]
# #### **문자열은 단어(word)를 나타낼 수 있다**

# %%
print('안녕')  # print 함수는 대상을 화면에 출력한다
# Out:
# 안녕

# %% [markdown]
# #### **문자열은 문장(sentence)도 나타낼 수 있다**

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %% [markdown]
# * string을 나타내기 위한 따옴표가 아니라, 실제 문장 부호의 따옴표를 쓰려면 어떻게 해야 하나?

# %%
print('你好는 한국어로 ' + "'안녕'" + '이라는 뜻이다')
# Out:
# 你好는 한국어로 '안녕'이라는 뜻이다

# %%
print("你好는 한국어로 '안녕'이라는 뜻이다")
# Out:
# 你好는 한국어로 '안녕'이라는 뜻이다

# %%
print('你好는 한국어로 '안녕'이라는 뜻이다')
# Out:
#   File "<ipython-input-17-b0e227909ff4>", line 1
#     print('你好는 한국어로 '안녕'이라는 뜻이다')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# * '문자 그대로임(literal)'을 나타내기 위해서 escape(\\) 가 필요하다<br>
# ```참고: 영문 자판의 역슬래시는 \가 아니다```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 왜 에러가 발생하는가?
print('\')
# Out:
#   File "<ipython-input-17-bb6bf29fcce9>", line 2
#     print('\')
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 왜 에러가 발생하는가?
print('\\')
# Out:
# \

# %%
# 그렇다면 역슬래시 \ 는 어떻게 나타내나? 따옴표(') 는?
print("역슬래시:\\, 따옴표:'")    # 쌍따옴표 같이 사용
# Out:
# 역슬래시:\, 따옴표:'

# %%
# or
print('역슬래시:\\, 따옴표:\'')        # escape문자 이용 ('\')
# Out:
# 역슬래시:\, 따옴표:'

# %%
print('역슬래시:' + '\\, 따옴표:' + "'"   )             # 내가 한 거
# Out:
# 역슬래시:\, 따옴표:'

# %%
print('你好'는 한국어로 '안녕'이라는 뜻이다)
# Out:
# '你好'는 한국어로 '안녕'이라는 뜻이다'

# %%
print(' \"o"/ ') # 왼손 어디갔어? 양손 번쩍!

# %%
print("'你好'는 한국어로 '안녕'이라는 뜻이다") # 쌍따옴표로 외따옴표와 차별화해도 된다

# %% [markdown]
# #### **두 줄(두 문장) 이상의 문단은 어떻게 표현하나?**

# %%
print(''''你好'는 한국어로 '안녕'이라는 뜻이다
'同学'는 '친구'라는 뜻이다
同学，你好！''')

# %% [markdown]
# ###**공백 문자 (Whitespace character)**
# 안 보이는 것들도 문자이다!
# *   스페이스: '&ensp;'
# *   줄바꿈(Enter): '\n'
# *   탭 : '\t'

# %%
' '
#print(' ')  # 안 보임.
#print('보'+' '+'임')

# %%
print('你好:\n안녕')
#print('你好:\n안녕') # \n 은 줄바꿈, \t는 TAB
# Out:
# 你好:
# 안녕

# %%
print('\'你好\'는 한국어로 \'안녕\'이라는 뜻이다.\'同学\'는 \'친구\'라는 뜻이다.同学，你好！')
# Out:
# '你好'는 한국어로 '안녕'이라는 뜻이다.'同学'는 '친구'라는 뜻이다.同学，你好！

# %% [markdown]
# * 위의 세 문장을 나누어서, 한줄에 한 문장씩 프린트 해보자

# %% [markdown]
# # 위치 참조(인덱싱, Indexing)

# %% [markdown]
#  * 리스트 인덱싱
# ```
# list[index]
# ```

# %%
z = [1,2,3,4,5]     # 리스트에 저장하기

# %%
type(z)    # z는 어떤 자료형(data type)인가? - list

# %%
print(z)      #  print 함수 사용하여 화면에 출력하기

# %%
len(z)    # 길이(length)가 어떻게 되나? : len 함수

# %%
z[0]    # 리스트의 첫 번째 요소 반환.  두 번째 요소 반환은?

# %%
z[-1]   # 리스트의 뒤에서 첫 번째 요소 반환.  뒤에서 두 번째 요소 반환은?

# %% [markdown]
# # 구간 편집 (슬라이싱, Slicing)

# %% [markdown]
# - 파이썬 리스트 구간 참조 (리스트 슬라이싱, list slicing) ▶ [예제](https://codetorial.net/tips_and_examples/list_slicing.html)
# ```
# list[start:end:step]
# ```

# %%
z[0:2]    # 리스트 슬라이싱. 0번째부터 두개 요소까지만. 주의: 마지막 인덱스는 포함되지 않음
# Out:
# [1, 2]

# %%
print(z)
z[0:4:2]    # 0번째부터 4개까지 2 걸음마로 |  처음부터 끝까지 2 걸음마로?
# Out:
# [1, 2, 3, 4, 5]
# [1, 3, 5]

# %%
z[::-1]    # reverse

# %% [markdown]
# # 문자열(string) 인덱싱 / 슬라이싱

# %%
s = '我是你爸爸'

# %%
len(s)     # 문자열 s의 길이
# Out:
# 5

# %%
s[1]     # 문자열은 리스트가 아님에도 불구하고, 리스트와 마찬가지로 인덱싱/슬라이싱이 가능하다
# Out:
# '是'

# %%
s[-3:-1]    # 무엇이 나오나?
# Out:
# '你爸'

# %%
s[::2]
# Out:
# '我你爸'

# %% [markdown]
# ### 문장 = 요소가 단어인 리스트(list)

# %% [markdown]
# * 문장(sentence)를 위의 `s`처럼 문자열로 저장할 수 있지만, 아래의 `sent`처럼 리스트 형태로 저장할 수도 있다

# %% [markdown]
# * (참고) [NLTK BOOK](https://https://www.nltk.org/book/ch01.html) 2절 A Closer Look at Python: Texts as Lists of Words

# %%
sent = ['word1', 'word2', 'word3', 'word4', 'word5',\
        'word6', 'word7', 'word8', 'word9', 'word10']

# %%
# 단어 인덱싱 (주의: 리스트의 첫 번째 요소 인덱스는 0 이다)
sent[0]
sent[9]
# Out:
# 'word10'

# %% [markdown]
# #### 말뭉치(corpus)를 살펴보자

# %%
# NLTK 로드 후 말뭉치 다운로드
import nltk
nltk.download('book')

# %%
from nltk.book import *

# %%
# NLTK 라이브러리에 포함된 책들
nltk.book.texts()

# %%
# 각 책들의 첫 문장들
nltk.book.sents()

# %%
# 창세기의 문두에 출현하는 어휘(word)들
genesis.words()
# Out:
# ['In', 'the', 'beginning', 'God', 'created', 'the', ...]

# %%
# 창세기의 끝에 출현하는 어휘(word)들
print(genesis.words()[-50:])
# Out:
# ['en', 'ed', 'av', 'Israels', 'barn', 'och', 'sade', ':', '╜', 'När', 'nu', 'Gud', 'ser', 'till', 'eder', ',', 'fören', 'då', 'mina', 'ben', 'härifrån', '.╜', 'Och', 'Josef', 'dog', ',', 'när', 'han', 'var', 'ett', 'hundra', 'tio', 'år', 'gammal', '.', 'Och', 'man', 'balsamerade', 'honom', ',', 'och', 'han', 'lades', 'i', 'en', 'kista', ',', 'i', 'Egypten', '.']

# %%
# 창세기의 문두에 출현하는 문장(sentence)들
genesis.sents()
# Out:
# [['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth', '.'], ['And', 'the', 'earth', 'was', 'without', 'form', ',', 'and', 'void', ';', 'and', 'darkness', 'was', 'upon', 'the', 'face', 'of', 'the', 'deep', '.'], ...]

# %%
# 창세기의 문두에 출현하는 첫번째 문장(sentence)
genesis.sents()[0]
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
# 창세기의 문두에 출현하는 첫번째 단락(paragraph)
genesis.paras()[0]

# %% [markdown]
# ## 특정 문자를 경계(delimiter, separator)로 삼아서 슬라이싱하기 ▶ str.split() 함수
# ```
# str.split(sep=None)
# ```

# %%
s = 'I am your father'
print(s)
# Out:
# I am your father

# %%
len(s)

# %%
# 공백 문자(스페이스, 탭, 줄바꿈)을 경계로 문자를 나누고, 리스트로 반환
s.split()
# Out:
# ['I', 'am', 'your', 'father']

# %%
sents = '我是你爸爸|I am your father|내가 니 애비다'

# %%
# pipe(|)를 기준으로 나눔
sents = sents.split('|')

# %%
print(sents)
# Out:
# ['我是你爸爸', 'I am your father', '내가 니 애비다']

# %% [markdown]
# ## 특정 문자를 접착제로 삼아서 이어 붙이기 ▶ str.join() 함수
# ```
# str.join(iterable)
# ```
#
# ```* An iterable is any Python object capable of returning its members one at a time```

# %%
print(sents)
# Out:
# ['我是你爸爸', 'I am your father', '내가 니 애비다']

# %%
type(sents)    # [ ] 로 둘러싸여 있으므로 string이 아니고 list 이다. 길이는?
# Out:
# list

# %%
print('\t'.join(sents))
# Out:
# 我是你爸爸	I am your father	내가 니 애비다

# %%
'****'.join(sents)    # string도 이어 붙이기 가능 (list와 마찬가지로 iterable 속성의 객체이므로)
# Out:
# '我是你爸爸****I am your father****내가 니 애비다'

# %% [markdown]
# ## 쓸모 없는 공백문자 벗어던지기 ▶ [str.strip()](https://docs.python.org/3/library/stdtypes.html?highlight=str%20strip#str.strip) 함수

# %%
comment = '''  头脑简单，只看外表。还不够成熟！
喜欢追求流行
   因为打扮的可飒可柔
Why do girls like Korean Wave?
   男生帅，女生美


   1장:  오늘의 커피

   2장:  내일의 커피   '''

# %%
len(comment.split('\n'))
# Out:
# 10

# %%
# 문장 개수는? 줄바꿈(\n)를 기준으로 세어 보자
sents = comment.split('\n')
print(sents)
len(sents) # 10개 문장?  7문장인데... 왜그럴까?
# Out:
# ['  头脑简单，只看外表。还不够成熟！', '喜欢追求流行', '   因为打扮的可飒可柔', 'Why do girls like Korean Wave?', '   男生帅，女生美', '', '', '   1장:  오늘의 커피', '', '   2장:  내일의 커피   ']
# 10

# %%
sents[4]
# Out:
# '   男生帅，女生美'

# %%
# str.strip() 양쪽에 있는 연속된 공백 삭제
sents[4].strip()  # https://docs.python.org/3/library/stdtypes.html?highlight=str%20strip#str.strip
# Out:
# '男生帅，女生美'

# %%
len(sents[4].strip())
# Out:
# 7

# %%
sents[0]
# Out:
# '  头脑简单，只看外表。还不够成熟！'

# %%
# If sep is not specified or is None, runs of consecutive whitespace are regarded as a single separator, and the result will contain no empty strings at the start or end if the string has leading or trailing whitespace.
sents[0].split() #
# Out:
# ['头脑简单，只看外表。还不够成熟！']

# %%
sents[0].split(' ') # https://docs.python.org/3/library/stdtypes.html?highlight=str%20strip#str.split
# Out:
# ['', '', '头脑简单，只看外表。还不够成熟！']

# %% [markdown]
# 이외에 더욱 다양한 문자열 처리는 4주차에 배울 **정규표현식**(Regular Expression)으로 수행하는 것이 효율적

# %% [markdown]
# ## 문자열 포매팅 (formatting, 규격화)<br>
#
# * str.format 메소드(함수)
#
# ```
# str.format(*args, **kwargs)  # arguments, keyword arguments
# ```
#
#
# *   입력값을 인수(arguments)로 받아서 작업을 수행한 후 결과값을 반환함
# *   PDF 교재 2-2의 `단어 빈도표 만들기 -  함수(function)` 설명 참조

# %%
'I eat %d apples' %3

# %%
print('{}是你爸爸'.format('朴老师'))    # single argument

# %%
print('{}是你{}'.format('同学','我'))   # arguments (순서 중요)

# %%
print('{person}是你{relation}'.format(relation='同学', person='我'))  # keyword arguments

# %%
I = '我'
teacher = '老师'

# %%
print('{p}是你{r}'.format(p=I, r=teacher))  # 변수를 활용하여 위와 동일하게 나오게 하려면?

# %%
# String Interpolation / f-Strings (Python 3.6+)
# Python 3.6 added a new string formatting approach called formatted string literals or “f-strings”.
print(f'{I}是你{teacher}')

# %% [markdown]
# 중국어 입력기 설치와 사용은 [공지사항 게시판] 참조

# %%
person = '朴敏浚'
class_ = 2002
comment = '                 囧囧囧 充满欢乐和痛苦，这叫人生。。。'

# %%
comment.strip()
# Out:
# '囧囧囧 充满欢乐和痛苦，这叫人生。。。'

# %% [markdown]
# 화면에 아래와 같이 출력되도록 print 함수에 들어갈 요소를 적어 보세요
#
# ```
# print(     )
# >>> 姓名：朴敏浚    年级：三年级    评论：囧囧囧 充满欢乐和痛苦，这叫人生。。。囧囧囧
# ```

# %%
print('姓名:{person} \t 年级：{cls} \t 评论:{comment}'.format(cls='四年级',  comment='囧囧囧 充满欢乐和痛苦，这叫人生。。。囧囧囧',person='朴敏浚'))

# %%
print('姓名：{p}\t年级：{}\t评论：{}'.format(class_,comment.strip(),p=person)) # keyword arguments는 순서와 관계 없음

# %%
print('datatype:{}'.format(type('d'))) # 데이터형(data type)에 관계 없이 모두 출력 가능함 -> %d, %s 등 방식보다 편리함
# Out:
# datatype:<class 'str'>

# %%
f'{person} 是 {class_} 班同学'  # 파이썬 3.6 버전부터 f접두사 포매팅 기능 제공
# Out:
# '朴敏浚 是 2002 班同学'

# %%
'{person} 是 {class_} 班同学'.format(person=person,class_=class_)
# Out:
# '朴敏浚 是 2002 班同学'

# %%
print('print\n안녕')  # r접두사(raw): 문자열에 사용된 이스케이프'\'를 이스케이프가 아닌 원시 문자열(raw string)으로 처리함
print(r'c:\program\twitter\notion')
# Out:
# print
# 안녕
# c:\program\twitter\notion

# %% [markdown]
# ## 반복문 (For 문)

# %% [markdown]
# 반복문 (for)으로 구구단 출력하기

# %% [markdown]
# 기본 문법<br>
#
#
# ```
# for i in iterable:                 # iterable 예: [1,2,3], '我爱你', (1,2,3), ...
#     i 에 대하여 수행할 작업         # 예: 곱하기 2
# ```

# %%
print(1)
print(2)
print(3)

# %%
for i in [1,2,3]:    # '我爱你德成女子大学' 도 가능함
  print(i)
# Out:
# 1
# 2
# 3

# %%
[x for x in [1,2,3,4,5] if x%2]
# Out:
# [1, 3, 5]

# %% [markdown]
# 반복문을 이용하여 문자열 처리하기

# %%
a='我' # 문자도 변수로 저장할 수 있다
b='爱'
c='德成女子大学'

# %%
for i in [a,b,c]:
  print(i)

# %%
print('我')
print('爱')
print('德成女子大学')

# %%
c = '德成'
d = '女子'
e = '大学'

# %%
c, d, e = '德成 女子 大学'.split()  # c를 더 잘게 나누려면? str.split() (기준은 space)

# %%
'*'.join(L)

# %%
print(a+b+c+d+e)  # 하나의 문장으로 만들기 / 하나의 문장으로 접착?  str.join() 함수 쓰기

# %%
# 마찬가지로 하나의 리스트에 저장할 수 있다
L = [a,b,c,d,e]
print(L)
# Out:
# ['我', '爱', '德成', '女子', '大学']

# %%
# 마찬가지로 반복문을 이용하여 처리할 수 있기
for token in L:  # a+b+c+d+e로 한다면 어떻게 출력될까?
  print(token+'!!!!!!!!!')
# Out:
# 我!!!!!!!!!
# 爱!!!!!!!!!
# 德成!!!!!!!!!
# 女子!!!!!!!!!
# 大学!!!!!!!!!

# %%
# 몇 번째 루프인지도 써 주기 : enumerate
for order, token in enumerate(L):
  print(order, token)  # 0번째부터 시작이므로
# Out:
# 0 我
# 1 爱
# 2 德成
# 3 女子
# 4 大学

# %%
# 짝수째 루프인지 알아보기 : modulo %  (참고: 교재 62-63쪽)
for order, token in enumerate(L):
  even = order%2  # 0 은 False, 1은 True
  print(even, token)
# Out:
# 0 我
# 1 爱
# 0 德成
# 1 女子
# 0 大学

# %%
# 제어문(조건문) if 써 보기  (참고: 교재 62-63쪽)
for order, token in enumerate(L):
  even = order%2
  if even :  # 1 (True) 이면 아래 print 함수 실행
    print(order+1, token)
# Out:
# 2 爱
# 4 女子

# %%
x = 1

# %%
if x:
  print('True')
# Out:
# True
